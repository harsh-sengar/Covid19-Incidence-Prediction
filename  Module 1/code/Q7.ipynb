# %%
import json
import numpy as np
import pandas as pd
from difflib import SequenceMatcher
from collections import OrderedDict 
import requests 
import csv

# %%
reader = csv.DictReader(open('district-id.csv'))

districtId = {}
for row in reader:
    key = row.pop('districtname')
    districtId[key] = list(row.values())[0]

# %%
casesWeek = {}
reader = csv.DictReader(open('cases-week.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (casesWeek)):
        casesWeek[key] = {}
    casesWeek[key][list(row.values())[0]] = list(row.values())[1] 

casesMonth = {}
reader = csv.DictReader(open('cases-month.csv')) 
for row in reader:
    key = row.pop('districtid')

    if(key not in (casesMonth)):
        casesMonth[key] = {}
    casesMonth[key][list(row.values())[0]] = list(row.values())[1] 
    
casesOverall = {}
reader = csv.DictReader(open('cases-overall.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (casesOverall)):
        casesOverall[key] = {}
    casesOverall[key][list(row.values())[0]] = list(row.values())[1]

# %%
neighborWeek = {}
reader = csv.DictReader(open('neighbor-week.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (neighborWeek)):
        neighborWeek[key] = {}
    neighborWeek[key][list(row.values())[0]] = {'neighbormean':list(row.values())[1],'neighborstdev':list(row.values())[2]}
neighborMonth = {}
reader = csv.DictReader(open('neighbor-month.csv')) 
for row in reader:
    key = row.pop('districtid')

    if(key not in (neighborMonth)):
        neighborMonth[key] = {}
    neighborMonth[key][list(row.values())[0]] = {'neighbormean':list(row.values())[1],'neighborstdev':list(row.values())[2]}
    
neighborOverall = {}
reader = csv.DictReader(open('neighbor-overall.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (neighborOverall)):
        neighborOverall[key] = {}
    neighborOverall[key][list(row.values())[0]] = {'neighbormean':list(row.values())[1],'neighborstdev':list(row.values())[2]}

# %%
stateWeek = {}
reader = csv.DictReader(open('state-week.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (stateWeek)):
        stateWeek[key] = {}
    stateWeek[key][list(row.values())[0]] = {'statemean':list(row.values())[1],'statestdev':list(row.values())[2]}

stateMonth = {}
reader = csv.DictReader(open('state-month.csv')) 
for row in reader:
    key = row.pop('districtid')

    if(key not in (stateMonth)):
        stateMonth[key] = {}
    stateMonth[key][list(row.values())[0]] = {'statemean':list(row.values())[1],'statestdev':list(row.values())[2]}
    
stateOverall = {}
reader = csv.DictReader(open('state-overall.csv')) 
for row in reader:
    key = row.pop('districtid')
    if(key not in (stateOverall)):
        stateOverall[key] = {}
    stateOverall[key][list(row.values())[0]] = {'statemean':list(row.values())[1],'statestdev':list(row.values())[2]}

# %%
hotcoldspotWeek = []
for week in range(1,26):
    week = str(week)
    for dId in districtId.values():
        if dId in neighborWeek and week in neighborWeek[dId]:
            if(float(casesWeek[dId][week]) > (float(neighborWeek[dId][week]['neighbormean']) + float(neighborWeek[dId][week]['neighborstdev']))):
                hotcoldspotWeek.append({'timeid':week ,'method': 'neighborhood' ,'spot': 'hot','districtid': dId})
            if(float(casesWeek[dId][week]) < (float(neighborWeek[dId][week]['neighbormean']) - float(neighborWeek[dId][week]['neighborstdev']))):
                hotcoldspotWeek.append({'timeid':week ,'method': 'neighborhood' ,'spot': 'cold','districtid': dId})
            
        if dId in stateWeek and week in stateWeek[dId]:
            if(float(casesWeek[dId][week]) > (float(stateWeek[dId][week]['statemean']) + float(stateWeek[dId][week]['statestdev']))):        
                hotcoldspotWeek.append({'timeid':week ,'method': 'state' ,'spot': 'hot','districtid': dId})
            if(float(casesWeek[dId][week]) < (float(stateWeek[dId][week]['statemean']) - float(stateWeek[dId][week]['statestdev']))):
                hotcoldspotWeek.append({'timeid':week ,'method': 'state' ,'spot': 'cold','districtid': dId})

            
hotcoldspotMonth = []
for month in range(1,8):
    month = str(month)
    for dId in districtId.values():
        if dId in neighborMonth and month in neighborMonth[dId]:
            if(float(casesMonth[dId][month]) > (float(neighborMonth[dId][month]['neighbormean']) + float(neighborMonth[dId][month]['neighborstdev']))):
                hotcoldspotMonth.append({'timeid':month ,'method': 'neighborhood' ,'spot': 'hot','districtid': dId})
            if(float(casesMonth[dId][month]) < (float(neighborMonth[dId][month]['neighbormean']) - float(neighborMonth[dId][month]['neighborstdev']))):
                hotcoldspotMonth.append({'timeid':month ,'method': 'neighborhood' ,'spot': 'cold','districtid': dId})
            
        if dId in stateMonth and month in stateMonth[dId]:
            if(float(casesMonth[dId][month]) > (float(stateMonth[dId][month]['statemean']) + float(stateMonth[dId][month]['statestdev']))):        
                hotcoldspotMonth.append({'timeid':month ,'method': 'state' ,'spot': 'hot','districtid': dId})
            if(float(casesMonth[dId][month]) < (float(stateMonth[dId][month]['statemean']) - float(stateMonth[dId][month]['statestdev']))):
                hotcoldspotMonth.append({'timeid':month ,'method': 'state' ,'spot': 'cold','districtid': dId})


hotcoldspotOverall = []
for overall in range(1,2):
    overall = str(overall)
    for dId in districtId.values():
        if dId in neighborOverall and overall in neighborOverall[dId]:
            if(float(casesOverall[dId][overall]) > (float(neighborOverall[dId][overall]['neighbormean']) + float(neighborOverall[dId][overall]['neighborstdev']))):
                hotcoldspotOverall.append({'timeid':overall ,'method': 'neighborhood' ,'spot': 'hot','districtid': dId})
            if(float(casesOverall[dId][overall]) < (float(neighborOverall[dId][overall]['neighbormean']) - float(neighborOverall[dId][overall]['neighborstdev']))):
                hotcoldspotOverall.append({'timeid':overall ,'method': 'neighborhood' ,'spot': 'cold','districtid': dId})
            
        if dId in stateOverall and overall in stateOverall[dId]:
            if(float(casesOverall[dId][overall]) > (float(stateOverall[dId][overall]['statemean']) + float(stateOverall[dId][overall]['statestdev']))):        
                hotcoldspotOverall.append({'timeid':overall ,'method': 'state' ,'spot': 'hot','districtid': dId})
            if(float(casesOverall[dId][overall]) < (float(stateOverall[dId][overall]['statemean']) - float(stateOverall[dId][overall]['statestdev']))):
                hotcoldspotOverall.append({'timeid':overall ,'method': 'state' ,'spot': 'cold','districtid': dId})

# %%
dfWeek = pd.DataFrame(hotcoldspotWeek) 
dfWeek.to_csv (r'method-spot-week.csv', index = False, header=True)

# %%
dfMonth = pd.DataFrame(hotcoldspotMonth) 
dfMonth.to_csv (r'method-spot-month.csv', index = False, header=True)

# %%
dfOverall = pd.DataFrame(hotcoldspotOverall) 
dfOverall.to_csv (r'method-spot-overall.csv', index = False, header=True)

# %%
hotcoldspotOverall
# Out:
# [{'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '102'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '103'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '104'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '104'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '109'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '110'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '113'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '113'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '115'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '116'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '119'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '124'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '127'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '133'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '136'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '137'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '138'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '142'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '145'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '146'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '154'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '155'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '162'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '165'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '165'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '167'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '169'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '170'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '176'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '179'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '179'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '180'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '184'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '185'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '202'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '203'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '206'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '206'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '208'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '208'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '210'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '212'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '212'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '217'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '221'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '225'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '226'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '227'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '228'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '229'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '231'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '232'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '234'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '235'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '239'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '240'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '240'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '249'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '250'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '252'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '257'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '257'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '260'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '260'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '262'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '267'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '267'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '268'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '270'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '270'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '271'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '276'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '277'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '277'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '278'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '282'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '286'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '289'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '292'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '293'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '294'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '294'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '301'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '303'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '304'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '304'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '307'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '309'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '309'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '310'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '310'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '314'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '315'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '316'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '318'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '318'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '320'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '321'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '323'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '324'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '329'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '329'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '332'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '332'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '333'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '333'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '335'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '335'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '336'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '337'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '339'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '342'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '342'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '344'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '354'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '355'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '356'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '357'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '358'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '360'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '360'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '364'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '369'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '378'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '382'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '382'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '383'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '385'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '387'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '391'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '398'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '399'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '400'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '405'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '405'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '408'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '408'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '409'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '410'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '411'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '412'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '413'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '413'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '416'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '416'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '417'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '418'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '418'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '419'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '420'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '425'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '425'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '429'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '429'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '431'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '433'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '434'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '443'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '445'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '445'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '446'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '449'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '450'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '454'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '454'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '455'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '455'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '456'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '456'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '457'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '458'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '459'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '463'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '463'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '469'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '469'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '470'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '478'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '480'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '481'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '487'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '488'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '489'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '493'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '493'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '498'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '499'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '506'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '507'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '513'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '519'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '523'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '526'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '526'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '529'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '535'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '536'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '537'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '538'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '542'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '544'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '545'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '546'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '546'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '548'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '550'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '552'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '552'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '553'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '553'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '556'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '557'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '560'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '562'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '563'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '565'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '566'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '566'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '567'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '567'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '571'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '571'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '574'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '579'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '579'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '583'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '584'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '585'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '591'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '591'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '593'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '599'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '600'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '605'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '606'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '607'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '611'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '622'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '624'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '627'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '629'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '631'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '634'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '636'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '639'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '641'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '641'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '642'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '646'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '648'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '649'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '652'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '661'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '663'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '665'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '666'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '666'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '669'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '672'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '672'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '677'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '678'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '679'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '682'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '682'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '686'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '686'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '699'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '707'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '708'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '710'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '712'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '713'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '715'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '718'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '718'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '721'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '724'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '726'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '731'},
#  {'timeid': '1', 'method': 'state', 'spot': 'cold', 'districtid': '732'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '734'},
#  {'timeid': '1',
#   'method': 'neighborhood',
#   'spot': 'cold',
#   'districtid': '736'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '737'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '740'},
#  {'timeid': '1', 'method': 'neighborhood', 'spot': 'hot', 'districtid': '742'},
#  {'timeid': '1', 'method': 'state', 'spot': 'hot', 'districtid': '742'}]
